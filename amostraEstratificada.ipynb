# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
base = pd.read_csv("DADOS/iris.csv")
base
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
base["class"].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
x , _, y, _ = train_test_split(base.iloc[:,4], base.iloc[:,4],
                              test_size = 0.7, stratify = base.iloc[:,4])

y.value_counts()

#DADOS UNIFORMES DADOS IGUAIS
# Out:
# class
# Iris-virginica     15
# Iris-setosa        15
# Iris-versicolor    15
# Name: count, dtype: int64

# %% [markdown]
# INFERT

# %%
infert = pd.read_csv("DADOS/infert.csv")
infert
# Out:
#      Unnamed: 0 education  age  parity  induced  case  spontaneous  stratum  \
# 0             1    0-5yrs   26       6        1     1            2        1
# 1             2    0-5yrs   42       1        1     1            0        2
# 2             3    0-5yrs   39       6        2     1            0        3
# 3             4    0-5yrs   34       4        2     1            0        4
# 4             5   6-11yrs   35       3        1     1            1        5
# ..          ...       ...  ...     ...      ...   ...          ...      ...
# 243         244   12+ yrs   31       1        0     0            1       79
# 244         245   12+ yrs   34       1        0     0            0       80
# 245         246   12+ yrs   35       2        2     0            0       81
# 246         247   12+ yrs   29       1        0     0            1       82
# 247         248   12+ yrs   23       1        0     0            1       83
#
#      pooled.stratum
# 0                 3
# ...

# %%
infert["education"].value_counts()
# Out:
# education
# 6-11yrs    120
# 12+ yrs    116
# 0-5yrs      12
# Name: count, dtype: int64

# %%
#                             colunas desejadas         a colunas principal a ser extraida
x1, _,y1, _ = train_test_split(infert.iloc[:,2:9], infert.iloc[:,1],
                          test_size = 0.6, stratify = infert.iloc[:,1])
y1.value_counts()
# Out:
# education
# 6-11yrs    48
# 12+ yrs    46
# 0-5yrs      5
# Name: count, dtype: int64
